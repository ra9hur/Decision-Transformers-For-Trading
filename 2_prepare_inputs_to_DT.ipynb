# %%
import os
import pandas as pd

from finrl.main import check_and_make_directories                               
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR

# "./" will be added in front of each directory
check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# ### Step1: Load the data

# %%
train = pd.read_csv('data/train.csv')

train = train.set_index(train.columns[0])
train.index.names = ['']

# %%
train.head()
# Out:
#          date       open       high        low      close     volume   tic  \
#
# 0  2009-01-02   3.067143   3.251429   3.041429   2.737005  746015200  AAPL
# 0  2009-01-02  58.590000  59.080002  57.750000  42.107323    6547900  AMGN
# 0  2009-01-02  18.570000  19.520000  18.400000  15.053307   10955700   AXP
# 0  2009-01-02  42.799999  45.560001  42.779999  33.941109    7010200    BA
# 0  2009-01-02  44.910000  46.980000  44.709999  30.712517    7117200   CAT
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
#
# 0    4   0.0  2.958118  2.631403   100.0  66.666667  100.0      2.737005
# 0    4   0.0  2.958118  2.631403   100.0  66.666667  100.0     42.107323
# 0    4   0.0  2.958118  2.631403   100.0  66.666667  100.0     15.053307
# 0    4   0.0  2.958118  2.631403   100.0  66.666667  100.0     33.941109
# 0    4   0.0  2.958118  2.631403   100.0  66.666667  100.0     30.712517
#
#    close_60_sma        vix  turbulence
#
# 0      2.737005  39.189999         0.0
# 0     42.107323  39.189999         0.0
# 0     15.053307  39.189999         0.0
# 0     33.941109  39.189999         0.0
# 0     30.712517  39.189999         0.0

# %%
train.shape
# Out:
# (98513, 18)

# %%
# train.columns
train.tic.unique(), INDICATORS
# Out:
# (array(['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS',
#         'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM',
#         'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT'],
#        dtype=object),
#  ['macd',
#   'boll_ub',
#   'boll_lb',
#   'rsi_30',
#   'cci_30',
#   'dx_30',
#   'close_30_sma',
#   'close_60_sma'])

# %% [markdown]
# ### Step 2: Setup the environment

# %% [markdown]
# state_space = 1 (remaining balance in the account) + 2stock_dimension (prices of 30 stocks and the share holdings of the 30 stocks, so totally 2stock_dimension) + len(INDICATORS)*stock_dimension

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %% [markdown]
# Action: The action space describes the allowed actions that the agent interacts with the environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# action is a scalar in a continuous space instead of a discrete space like {-1, 0, 1}. Hence, we just need one action for each stock, and that action is from a continuous space. Thus the action is always a vector with stock dimension.

# %%
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

e_train_gym = StockTradingEnv(df = train, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()

# %%
len(e_train_gym.df.index.unique()) - 1
# Out:
# 3396

# %%
e_train_gym.df.tic.count()
# Out:
# 98513

# %% [markdown]
# ### Step 3: Initially train using a PPO Model

# %%
from stable_baselines3 import PPO
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure

agent = DRLAgent(env = env_train)
model_ppo = agent.get_model('ppo')

# set up logger
tmp_path = RESULTS_DIR + '/ppo'
new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_ppo.set_logger(new_logger_ppo)

trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 64}
# Using cpu device
# Logging to results/ppo
# ------------------------------------
# | time/              |             |
# |    fps             | 205         |
# |    iterations      | 1           |
# |    time_elapsed    | 9           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.09338944 |
# ------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 2           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014445987 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00235     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.79        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.022      |
# |    reward               | 0.23056176  |
# |    std                  | 1           |
# |    value_loss           | 13.4        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 51        |
# |    iterations           | 3         |
# |    time_elapsed         | 120       |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0176178 |
# |    clip_fraction        | 0.163     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -41.2     |
# |    explained_variance   | 0.000747  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 41        |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.0181   |
# |    reward               | -4.257323 |
# |    std                  | 1         |
# |    value_loss           | 76.5      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 4           |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019225052 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00117    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | 0.2443117   |
# |    std                  | 1           |
# |    value_loss           | 40.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 5           |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017150369 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00046     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 48.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0144     |
# |    reward               | -0.40910324 |
# |    std                  | 1.01        |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 6           |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.02160871  |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0184     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 71.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.012      |
# |    reward               | -0.22271843 |
# |    std                  | 1.01        |
# |    value_loss           | 206         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 7           |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.027987815 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0787     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.61        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0178     |
# |    reward               | 4.0513816   |
# |    std                  | 1.01        |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 8          |
# |    time_elapsed         | 404        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02595453 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.5      |
# |    explained_variance   | 0.00262    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 49.3       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00971   |
# |    reward               | 4.8622336  |
# |    std                  | 1.01       |
# |    value_loss           | 106        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 9           |
# |    time_elapsed         | 463         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.031237252 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00432     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0104     |
# |    reward               | -0.3948542  |
# |    std                  | 1.01        |
# |    value_loss           | 55.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 10          |
# |    time_elapsed         | 517         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018465728 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0.00843     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 115         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0131     |
# |    reward               | 1.113584    |
# |    std                  | 1.01        |
# |    value_loss           | 152         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 11          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.031533808 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0105     |
# |    reward               | 0.18561445  |
# |    std                  | 1.01        |
# |    value_loss           | 83.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 12          |
# |    time_elapsed         | 626         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.031710744 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0395     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.68        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00979    |
# |    reward               | -0.09541256 |
# |    std                  | 1.02        |
# |    value_loss           | 16.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 13          |
# |    time_elapsed         | 679         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.028609127 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0.013       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 104         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | -0.85751873 |
# |    std                  | 1.02        |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 14          |
# |    time_elapsed         | 732         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.030430498 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.00427     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 25.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0137     |
# |    reward               | 1.568127    |
# |    std                  | 1.02        |
# |    value_loss           | 103         |
# -----------------------------------------
# day: 3396, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5715506.74
# total_reward: 4715506.74
# total_cost: 423492.10
# total_trades: 91919
# Sharpe: 0.880
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 15          |
# |    time_elapsed         | 783         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023920197 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.00231     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 60.6        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0171     |
# |    reward               | 0.27182004  |
# |    std                  | 1.03        |
# |    value_loss           | 156         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 16          |
# |    time_elapsed         | 835         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.037839137 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 48.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0067     |
# |    reward               | -3.1356816  |
# |    std                  | 1.03        |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 17          |
# |    time_elapsed         | 886         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.039873704 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.0667     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.97        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00783    |
# |    reward               | 0.1246749   |
# |    std                  | 1.03        |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 18          |
# |    time_elapsed         | 939         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026596062 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | -0.00272    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 72.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00676    |
# |    reward               | 1.9836739   |
# |    std                  | 1.03        |
# |    value_loss           | 235         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 19          |
# |    time_elapsed         | 991         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.039258383 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | -0.00732    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 58.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0062     |
# |    reward               | -0.52342474 |
# |    std                  | 1.04        |
# |    value_loss           | 65.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 20          |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.02946789  |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.00668     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0102     |
# |    reward               | -0.22971502 |
# |    std                  | 1.04        |
# |    value_loss           | 75.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 21         |
# |    time_elapsed         | 1093       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02352212 |
# |    clip_fraction        | 0.274      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.3      |
# |    explained_variance   | 0.0078     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 142        |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00507   |
# |    reward               | 3.7990227  |
# |    std                  | 1.04       |
# |    value_loss           | 188        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 22          |
# |    time_elapsed         | 1144        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031340584 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -0.0102     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.65        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0048     |
# |    reward               | -1.8245037  |
# |    std                  | 1.05        |
# |    value_loss           | 22.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 23          |
# |    time_elapsed         | 1196        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.031405732 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | 0.015       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 52.3        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0126     |
# |    reward               | -3.4190207  |
# |    std                  | 1.05        |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 24          |
# |    time_elapsed         | 1248        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.029760472 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | -0.00415    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.012      |
# |    reward               | -0.72328764 |
# |    std                  | 1.05        |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 25          |
# |    time_elapsed         | 1299        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.026626846 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.6       |
# |    explained_variance   | 0.0128      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0115     |
# |    reward               | 0.6250054   |
# |    std                  | 1.05        |
# |    value_loss           | 89.1        |
# -----------------------------------------

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo")

# %%
# Load the saved model

model = PPO.load("trained_models/agent_ppo.zip")

# %% [markdown]
# ### Step 4: Use PPO Model to generate trajectories

# %%
import numpy as np

"""make a prediction and get results"""
env_train, obs = e_train_gym.get_sb_env()

ds = []
states = []
feature = {}

s, a, r, d = [], [], [], []

env_train.reset()
#max_steps = len(e_train_gym.df.index.unique()) - 1
max_steps = e_train_gym.df.tic.count() - 1

for i in range(1, max_steps, 1):

    action, _states = model.predict(obs, deterministic=True)
    s.extend(obs)
    a.extend(action)

    obs, rewards, dones, info = env_train.step(action)
    r.extend(rewards)
    d.append(dones[0])

    states.extend(obs)

    if (i % 100 == 0):
        
        feature['observations'] = s
        feature['actions'] = a
        feature['rewards'] = r
        feature['dones'] = d
        
        ds.append(feature)
        feature = {}
        s, a, r, d = [], [], [], []


states = np.vstack(states)
state_mean, state_std = np.mean(states, axis=0), np.std(states, axis=0) + 1e-6
# Out:
# day: 3396, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 5230959.83
# total_reward: 4230959.83
# total_cost: 3335.23
# total_trades: 40903
# Sharpe: 0.741
# =================================
# day: 3396, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 5230959.83
# total_reward: 4230959.83
# total_cost: 3335.23
# total_trades: 40903
# Sharpe: 0.741
# =================================
# day: 3396, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 5230959.83
# total_reward: 4230959.83
# total_cost: 3335.23
# total_trades: 40903
# Sharpe: 0.741
# =================================

# %%
state_mean[:5], state_std[:5], state_mean.shape
# Out:
# (array([5.2268852e+04, 4.1985973e+01, 1.1738811e+02, 7.5283417e+01,
#         1.5208690e+02], dtype=float32),
#  array([1.8320502e+05, 4.3432262e+01, 6.1657406e+01, 3.8436382e+01,
#         1.0245751e+02], dtype=float32),
#  (291,))

# %%
len_ds = len(ds)

state_mean = np.pad(state_mean, (0, (len_ds-state_space)))
state_std = np.pad(state_std, (0, (len_ds-state_space)))

# %%
state_mean, len(state_mean)
# Out:
# (array([5.22688516e+04, 4.19859734e+01, 1.17388107e+02, 7.52834167e+01,
#         1.52086899e+02, 9.21457214e+01, 9.42755127e+01, 2.57341862e+01,
#         7.48008575e+01, 8.51193771e+01, 1.67372482e+02, 1.17778442e+02,
#         9.47928238e+01, 1.00966560e+02, 2.87876167e+01, 8.75014572e+01,
#         6.35456352e+01, 3.27508621e+01, 1.11384789e+02, 9.10166245e+01,
#         4.33551979e+01, 8.26768723e+01, 5.52649345e+01, 7.18913956e+01,
#         8.55227356e+01, 1.49126968e+02, 8.91049500e+01, 3.11658859e+01,
#         4.08236771e+01, 2.44139862e+01, 1.52551978e+03, 3.12602466e+03,
#         3.24999243e-01, 5.69125098e+03, 1.07546783e+02, 4.24570557e+03,
#         1.76630018e-03, 9.71465092e-03, 1.21795642e+03, 0.00000000e+00,
#         1.06861159e-01, 0.00000000e+00, 3.66832123e+02, 7.93789429e+02,
#         5.02173309e+02, 3.53554428e-01, 0.00000000e+00, 1.79031543e+03,
#         0.00000000e+00, 4.74454468e+02, 5.03509094e+02, 0.00000000e+00,
#         5.00036182e+03, 4.45463330e+03, 6.20528015e+02, 1.91789612e+02,
#         1.19846413e+02, 8.24273471e-03, 3.53260036e-03, 2.85135627e-01,
#         3.86063933e-01, 2.82519758e-01, 2.14620367e-01, 3.52440149e-01,
#         3.39403272e-01, 6.38446659e-02, 2.32297525e-01, 1.72620758e-01,
#         4.57934618e-01, 5.31106234e-01, 3.24153692e-01, 1.53653592e-01,
#         6.11994378e-02, 2.66264588e-01, 1.97871342e-01, 9.23971981e-02,
#         3.99168342e-01, 1.58715338e-01, 1.40132084e-01, 5.01628280e-01,
#         2.07447618e-01, 2.04812557e-01, 2.77267516e-01, 9.32848215e-01,
#         3.86010915e-01, 6.18191846e-02, 4.22456600e-02, 5.93820848e-02,
#         4.41871147e+01, 1.22622795e+02, 7.90774536e+01, 1.62202103e+02,
#         9.73476028e+01, 1.00222694e+02, 2.69546623e+01, 7.82152252e+01,
#         8.90514679e+01, 1.76398087e+02, 1.22736320e+02, 9.84012070e+01,
#         1.05035164e+02, 3.03895168e+01, 9.00408401e+01, 6.67320175e+01,
#         3.37170181e+01, 1.14767914e+02, 9.45593491e+01, 4.49903450e+01,
#         8.61245422e+01, 5.79891930e+01, 7.39641342e+01, 8.85564041e+01,
#         1.55275711e+02, 9.27382431e+01, 3.21860580e+01, 4.29333534e+01,
#         2.52624397e+01, 3.90396347e+01, 1.11097717e+02, 7.07799683e+01,
#         1.41380692e+02, 8.60551300e+01, 8.74118423e+01, 2.43451900e+01,
#         7.07942810e+01, 8.07567139e+01, 1.57120850e+02, 1.11428307e+02,
#         9.03334732e+01, 9.64377213e+01, 2.70329437e+01, 8.42234955e+01,
#         5.98415947e+01, 3.15309410e+01, 1.06903740e+02, 8.70721817e+01,
#         4.13320007e+01, 7.78912582e+01, 5.20047340e+01, 6.92711258e+01,
#         8.17486420e+01, 1.40424576e+02, 8.44434814e+01, 2.99730892e+01,
#         3.85975380e+01, 2.34125500e+01, 5.56787529e+01, 5.25796547e+01,
#         5.34438095e+01, 5.30707474e+01, 5.25341263e+01, 5.35147514e+01,
#         5.25616837e+01, 5.22658424e+01, 5.30132103e+01, 5.19732971e+01,
#         5.50610542e+01, 5.40022850e+01, 5.17083359e+01, 5.21755486e+01,
#         5.37307968e+01, 5.29435692e+01, 5.34704742e+01, 5.39139442e+01,
#         5.30448570e+01, 5.26770096e+01, 5.46670265e+01, 5.36698189e+01,
#         5.28686295e+01, 5.33540421e+01, 5.47942581e+01, 5.46632271e+01,
#         5.20768814e+01, 5.15708389e+01, 5.24264145e+01, 3.57979355e+01,
#         1.54569464e+01, 2.56224251e+01, 1.97687073e+01, 2.08197041e+01,
#         2.89878826e+01, 1.66911240e+01, 1.31888523e+01, 2.35213737e+01,
#         1.26575880e+01, 3.18225040e+01, 3.07703228e+01, 1.35260429e+01,
#         1.66190662e+01, 1.97595329e+01, 2.11939716e+01, 2.38151760e+01,
#         2.93240929e+01, 2.33051968e+01, 1.78439789e+01, 3.67141800e+01,
#         2.60013599e+01, 1.92359676e+01, 2.19047394e+01, 3.67194023e+01,
#         3.90365562e+01, 2.88645363e+00, 5.23168802e+00, 1.79273529e+01,
#         2.53746109e+01, 2.33861504e+01, 2.21633835e+01, 2.24694195e+01,
#         2.32995205e+01, 2.33160019e+01, 2.38773537e+01, 2.28435993e+01,
#         2.41494427e+01, 2.32398567e+01, 2.48877316e+01, 2.16529827e+01,
#         2.21138783e+01, 2.28788757e+01, 2.24155121e+01, 2.18842392e+01,
#         2.12228928e+01, 2.22435760e+01, 2.20814781e+01, 2.14497566e+01,
#         2.30366135e+01, 2.38014183e+01, 2.30735950e+01, 2.23943291e+01,
#         2.32202625e+01, 2.19465866e+01, 2.21091824e+01, 2.42138119e+01,
#         2.34167805e+01, 4.14109383e+01, 1.16594307e+02, 7.47250748e+01,
#         1.51653503e+02, 9.14511490e+01, 9.35768967e+01, 2.56083870e+01,
#         7.43439636e+01, 8.47860413e+01, 1.66442657e+02, 1.16704918e+02,
#         9.41391525e+01, 1.00637581e+02, 2.86693611e+01, 8.69562073e+01,
#         6.31490402e+01, 3.25619431e+01, 1.10559074e+02, 9.07071609e+01,
#         4.30647583e+01, 8.16532745e+01, 5.48490219e+01, 7.14847107e+01,
#         8.49634171e+01, 1.47188629e+02, 8.83118057e+01, 3.10381603e+01,
#         4.07383194e+01, 2.43002605e+01, 4.07748222e+01, 1.15759743e+02,
#         7.40836029e+01, 1.51176651e+02, 9.06651917e+01, 9.28564606e+01,
#         2.54624691e+01, 7.38297195e+01, 8.43887253e+01, 1.65431641e+02,
#         1.15539513e+02, 9.34249039e+01, 1.00319923e+02, 2.85273972e+01,
#         8.63762589e+01, 6.27133980e+01, 3.23582458e+01, 1.09697243e+02,
#         9.03480835e+01, 4.27626648e+01, 8.05550461e+01, 5.43937798e+01,
#         7.10144882e+01, 8.43528290e+01, 1.45166245e+02, 8.74750061e+01,
#         3.09066467e+01, 4.06442146e+01, 2.41589184e+01, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00], dtype=float32),
#  985)

# %%
len(ds), len(ds[0])
# Out:
# (985, 4)

# %%
feature = ds[0]
len(feature["rewards"])
# Out:
# 100

# %% [markdown]
# https://huggingface.co/docs/datasets/v1.11.0/loading_datasets.html#from-local-files
#
# csv
# - dataset = load_dataset(‘csv’, data_files=[‘my_file_1.csv’, ‘my_file_2.csv’])
#
# json
# - dataset = load_dataset(‘json’, data_files=’my_file.json’)
#
# text
# - dataset = load_dataset(‘text’, data_files={‘train’: [‘my_text_1.txt’, ‘my_text_2.txt’], ‘test’: ‘my_test_file.txt’})
#
# python dict
# - my_dict = {'id': [0, 1, 2], 'name': ['mary', 'bob', 'eve'], 'age': [24, 53, 19]}
# - dataset = Dataset.from_dict(my_dict)
#
# pandas dataframe
# - df = pd.DataFrame({"a": [1, 2, 3]})
# - dataset = Dataset.from_pandas(df)

# %% [markdown]
# ### Step 5: Wrap the trajectory data using a dictionary

# %%
input_data = {}
input_data['train'] = ds
input_data['state_mean'] = state_mean
input_data['state_std'] = state_std

# %%
input_data.keys()
# Out:
# dict_keys(['train', 'state_mean', 'state_std'])

# %%
from datasets import Dataset

dataset = Dataset.from_dict(input_data)

# %% [markdown]
# ### Step 6: Save the trajectory data to the local disk

# %% [markdown]
# https://huggingface.co/docs/datasets/v1.10.2/processing.html

# %%
dataset.save_to_disk("data/dataset/")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/985 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk

dataset = load_from_disk("data/dataset/")
